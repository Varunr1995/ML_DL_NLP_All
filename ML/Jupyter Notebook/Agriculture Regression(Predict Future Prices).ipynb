# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("G:/Education/Machine Learning/ML_CSV_FILES/agricultural_raw_material.csv")
df.head()
# Out:
#     Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 0  Apr-90            482.34                          -         236
# 1  May-90            447.26                     -7.27%         234
# 2  Jun-90            440.99                     -1.40%         216
# 3  Jul-90            418.44                     -5.11%         205
# 4  Aug-90            418.44                      0.00%         198
#
#   Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# 0                    -          1.83                     -        1,071.63
# 1               -0.85%          1.89                 3.28%        1,057.18
# 2               -7.69%          1.99                 5.29%          898.24
# 3               -5.09%          2.01                 1.01%          895.83
# 4               -3.41%          1.79               -10.95%          951.22
#
#   Fine wool price % Change  Hard log Price  ... Plywood Price  \
# ...

# %%
df = df.replace('%', '', regex=True)
df = df.replace(',', '', regex=True)
df = df.replace('-', '', regex=True)
df = df.replace('', np.nan)
df = df.replace('MAY90', np.nan)

# %%
df.isnull().sum()
# Out:
# Month                            0
# Coarse wool Price               34
# Coarse wool price % Change      35
# Copra Price                     22
# Copra price % Change            23
# Cotton Price                     0
# Cotton price % Change            1
# Fine wool Price                 34
# Fine wool price % Change        35
# Hard log Price                   0
# Hard log price % Change          1
# Hard sawnwood Price             34
# Hard sawnwood price % Change    35
# Hide Price                      34
# Hide price % change             35
# Plywood Price                    0
# Plywood price % Change           1
# Rubber Price                     0
# Rubber price % Change            1
# Softlog Price                   34
# Softlog price % Change          35
# Soft sawnwood Price             34
# Soft sawnwood price % Change    35
# Wood pulp Price                  1
# Wood pulp price % Change         2
# dtype: int64

# %%
df = df.dropna()

# %%
list = ["Coarse wool Price","Coarse wool price % Change","Copra Price","Copra price % Change","Cotton Price","Cotton price % Change","Fine wool Price","Fine wool price % Change","Hard log Price","Hard log price % Change","Hard sawnwood Price","Hard sawnwood price % Change","Hide Price","Hide price % change","Plywood Price","Plywood price % Change","Rubber Price","Rubber price % Change","Softlog Price","Softlog price % Change","Soft sawnwood Price","Soft sawnwood price % Change","Wood pulp Price","Wood pulp price % Change"]
df[list] = df[list].astype("float")

# %%
df.dtypes
# Out:
# Month                            object
# Coarse wool Price               float64
# Coarse wool price % Change      float64
# Copra Price                     float64
# Copra price % Change            float64
# Cotton Price                    float64
# Cotton price % Change           float64
# Fine wool Price                 float64
# Fine wool price % Change        float64
# Hard log Price                  float64
# Hard log price % Change         float64
# Hard sawnwood Price             float64
# Hard sawnwood price % Change    float64
# Hide Price                      float64
# Hide price % change             float64
# Plywood Price                   float64
# Plywood price % Change          float64
# Rubber Price                    float64
# Rubber price % Change           float64
# Softlog Price                   float64
# Softlog price % Change          float64
# Soft sawnwood Price             float64
# Soft sawnwood price % Change    float64
# ...

# %%
df.Month = pd.to_datetime(df.Month.str.upper(), format = '%b%y', yearfirst = False)
df = df.set_index('Month')

# %% [markdown]
# ### COARSE WOOL PRICES

# %%
price = df[["Coarse wool Price", "Coarse wool price % Change"]].plot(figsize = (11, 9), subplots = True, linewidth = 1)

# %% [markdown]
# ### COPRA PRICE

# %%
price = df[["Copra Price", "Copra price % Change"]].plot(figsize = (11, 9), subplots = True, linewidth = 1)

# %% [markdown]
# ### COTTON PRICE

# %%
price = df[["Cotton Price", "Cotton price % Change"]].plot(figsize = (11, 9), subplots = True, linewidth = 1)

# %% [markdown]
# ### FINE WOOL PRICE

# %%
price = df[["Fine wool Price", "Fine wool price % Change"]].plot(figsize = (11, 9), subplots = True, linewidth = 1)

# %% [markdown]
# ### HARD LOG PRICE

# %%
price = df[["Hard log Price", "Hard log price % Change"]].plot(figsize = (11, 9), subplots = True, linewidth = 1)

# %% [markdown]
# ### HARD SAWNOOD PRICE

# %%
price = df[["Hard sawnwood Price", "Hard sawnwood price % Change"]].plot(figsize = (11, 9), subplots = True, linewidth = 1)

# %% [markdown]
# ### HIDE PRICE

# %%
price = df[["Hide Price", "Hide price % change"]].plot(figsize = (11, 9), subplots = True, linewidth = 1)

# %% [markdown]
# ### PLYWOOD PRICE

# %%
price = df[["Plywood Price", "Plywood price % Change"]].plot(figsize = (11, 9), subplots = True, linewidth = 1)

# %% [markdown]
# ### RUBBER PRICE

# %%
price = df[["Rubber Price", "Rubber price % Change"]].plot(figsize = (11, 9), subplots = True, linewidth = 1)

# %% [markdown]
# ### SOFTLOG PRICE

# %%
price = df[["Softlog Price", "Softlog price % Change"]].plot(figsize = (11, 9), subplots = True, linewidth = 1)

# %% [markdown]
# ### SOFT SAWNWOOD PRICE

# %%
price = df[["Soft sawnwood Price", "Soft sawnwood price % Change"]].plot(figsize = (11, 9), subplots = True, linewidth = 1)

# %% [markdown]
# ### WOOD PULP PRICE

# %%
price = df[["Wood pulp Price", "Wood pulp price % Change"]].plot(figsize = (11, 9), subplots = True, linewidth = 1)

# %% [markdown]
# # ANALYSIS

# %%
df.dtypes
# Out:
# Coarse wool Price               float64
# Coarse wool price % Change      float64
# Copra Price                     float64
# Copra price % Change            float64
# Cotton Price                    float64
# Cotton price % Change           float64
# Fine wool Price                 float64
# Fine wool price % Change        float64
# Hard log Price                  float64
# Hard log price % Change         float64
# Hard sawnwood Price             float64
# Hard sawnwood price % Change    float64
# Hide Price                      float64
# Hide price % change             float64
# Plywood Price                   float64
# Plywood price % Change          float64
# Rubber Price                    float64
# Rubber price % Change           float64
# Softlog Price                   float64
# Softlog price % Change          float64
# Soft sawnwood Price             float64
# Soft sawnwood price % Change    float64
# Wood pulp Price                 float64
# ...

# %%
x = df[["Coarse wool Price"]].values
y = df[["Coarse wool price % Change"]].values

# %%
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ## TRAINING TEST DATA

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 1/3, random_state = 0)

# %% [markdown]
# #### LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
prediction = lr.predict(x_test)

# %%
accuracy_score(y_test, prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-29a626ff9959> in <module>
# ----> 1 accuracy_score(y_test, prediction)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     183
#     184     # Compute accuracy for each possible representation
# --> 185     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     186     check_consistent_length(y_true, y_pred, sample_weight)
#     187     if y_type.startswith('multilabel'):
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      95     # No metrics support "multiclass-multioutput" format
#      96     if (y_type not in ["binary", "multiclass", "multilabel-indicator"]):
# ---> 97         raise ValueError("{0} is not supported".format(y_type))
#      98
# ...
