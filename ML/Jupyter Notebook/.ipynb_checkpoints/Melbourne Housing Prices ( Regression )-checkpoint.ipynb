# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("G:/Education/Machine Learning/ML_DATA_FILES/Linear Regression ( Melbourne Housing Prices )/Melbourne_housing_FULL.csv")
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
region = df['Regionname'].unique()
region
# Out:
# array(['Northern Metropolitan', 'Western Metropolitan',
#        'Southern Metropolitan', 'Eastern Metropolitan',
#        'South-Eastern Metropolitan', 'Eastern Victoria',
#        'Northern Victoria', 'Western Victoria', nan], dtype=object)

# %%
property_count_min = np.min(df.Propertycount)
property_count_max = np.max(df.Propertycount)
print("Property Count Minimum: ", property_count_min)
print("Property Count Maximum: ", property_count_max)
# Out:
# Property Count Minimum:  83.0
# Property Count Maximum:  21650.0

# %%
minimum_price = np.min(df.Price)
maximum_price = np.max(df.Price)
print("Minimum Price:", minimum_price)
print("Maximum Price:", maximum_price)
# Out:
# Minimum Price: 85000.0
# Maximum Price: 11200000.0

# %%
price = np.mean(df.Price)
price
# Out:
# 1050173.344955408

# %%
df.Price = df.Price.fillna(price)

# %%
distance = np.mean(df.Distance)
distance
# Out:
# 11.18492942391554

# %%
df.Distance = df.Distance.fillna(distance)

# %%
plt.figure(figsize=(20,10))
sns.countplot('Regionname', data = df)
plt.title("Houses prices in melbourne city")
# Out:
# Text(0.5, 1.0, 'Houses prices in melbourne city')

# %%
plt.figure(figsize = (50,30))
sns.scatterplot('Longtitude', 'Lattitude', hue = 'Regionname', data = df)

# %%
plt.figure(figsize = (50,30))
sns.scatterplot('Longtitude', 'Lattitude', hue = 'CouncilArea', data = df)

# %%
fig = sns.regplot(x = "Rooms", y = "Bathroom", data = df)
plt.title("Rooms Vs BathRoom")
plt.show()

# %%
plt.figure(figsize =(10,10))
sns.heatmap(df.corr(),annot= True,cmap = 'rocket')

# %%
df.drop(['Postcode', 'Longtitude', 'Lattitude', 'Regionname', 'BuildingArea', 'Propertycount', 'Landsize', 'YearBuilt', 'CouncilArea'], axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# Suburb         0
# Address        0
# Rooms          0
# Type           0
# Price          0
# Method         0
# SellerG        0
# Date           0
# Distance       0
# Bedroom2    8217
# Bathroom    8226
# Car         8728
# dtype: int64

# %%
df["Date"] = pd.to_datetime(df["Date"], dayfirst=True)

# %%
len(df["Date"].unique())/4 # 12 represents the data related to an year. #
# Out:
# 19.5

# %%
df[df["Type"] == "h"].sort_values("Date", ascending = False).groupby("Date").mean()
# Out:
#                Rooms         Price   Distance  Bedroom2  Bathroom       Car
# Date
# 2016-01-28  3.500000  1.127587e+06  10.100000  3.500000  1.500000  1.000000
# 2016-02-04  2.958333  1.065768e+06  10.245833  2.842105  1.368421  1.842105
# 2016-04-16  3.271552  1.189183e+06   8.964655  3.089947  1.645503  1.645503
# 2016-04-23  3.181818  1.079682e+06   8.721818  3.034483  1.459770  1.528736
# 2016-05-07  3.279152  1.216273e+06   8.995760  3.164502  1.627706  1.670996
# ...              ...           ...        ...       ...       ...       ...
# 2018-02-17  3.342466  1.080144e+06  14.250959  3.367089  1.737342  2.006711
# 2018-02-24  3.421131  1.178403e+06  12.939286  3.437401  1.752381  2.033841
# 2018-03-03  3.439065  1.193451e+06  12.985476  3.460145  1.776770  2.025000
# 2018-03-10  3.581967  9.148192e+05  16.341803  3.601770  1.840708  1.990991
# 2018-03-17  3.414465  1.176711e+06  13.336718  3.441441  1.750751  1.964174
#
# [78 rows x 6 columns]

# %%
pd.set_eng_float_format(accuracy=1, use_eng_prefix=True)
df[(df["Type"] == "h") & 
   (df["Distance"]<14) &
   (df["Distance"]>13.5)].sort_values("Date", ascending = False).dropna().groupby(["Suburb", "SellerG"]).mean()
# Out:
#                     Rooms   Price  Distance  Bedroom2  Bathroom  Car
# Suburb   SellerG
# Albion   Barry        2.3  651.6k      13.9       2.3       1.0  1.3
#          Bells        3.0  784.2k      13.9       3.2       1.2  2.5
#          Douglas      3.5  680.0k      13.9       3.5       1.0  1.5
#          FN           3.0  625.0k      13.9       3.0       1.0  0.0
#          Sweeney      3.0  637.7k      13.9       3.0       1.3  1.3
# ...                   ...     ...       ...       ...       ...  ...
# Viewbank Fletchers    3.5    1.1M      13.8       3.5       1.5  2.0
#          Miles        3.7  972.7k      13.8       3.8       2.1  1.9
#          Morrison     3.0  820.0k      13.8       3.0       2.0  2.0
#          Nelson       3.9  962.6k      13.8       4.0       2.0  2.0
#          Ray          3.0  765.0k      13.8       3.0       1.0  2.0
#
# [111 rows x 6 columns]

# %%
import math
Bedroom_Mean = math.floor(df['Bedroom2'].mean())
Bathroom_Mean = math.floor(df['Bathroom'].mean())
Car_Mean = math.floor(df['Car'].mean())

# %%
df.Bedroom2 = df['Bedroom2'].fillna(Bedroom_Mean)
df.Bathroom = df['Bathroom'].fillna(Bathroom_Mean)
df.Car = df['Car'].fillna(Car_Mean)

# %%
df.isnull().sum()
# Out:
# Suburb      0
# Address     0
# Rooms       0
# Type        0
# Price       0
# Method      0
# SellerG     0
# Date        0
# Distance    0
# Bedroom2    0
# Bathroom    0
# Car         0
# dtype: int64

# %%
df.Type.unique()
# Out:
# array(['h', 'u', 't'], dtype=object)

# %%
df.Method.unique()
# Out:
# array(['SS', 'S', 'VB', 'SP', 'PI', 'SN', 'W', 'PN', 'SA'], dtype=object)

# %%
df.dtypes
# Out:
# Suburb              object
# Address             object
# Rooms                int64
# Type                object
# Price              float64
# Method              object
# SellerG             object
# Date        datetime64[ns]
# Distance           float64
# Bedroom2           float64
# Bathroom           float64
# Car                float64
# dtype: object

# %%
df.drop(['Suburb', 'Address', 'Method', 'SellerG', 'Date'], axis = 1, inplace = True)

# %%
df['Type'] = pd.get_dummies(df['Type'])

# %%
df.dtypes
# Out:
# Rooms         int64
# Type          uint8
# Price       float64
# Distance    float64
# Bedroom2    float64
# Bathroom    float64
# Car         float64
# dtype: object

# %%
x = df.drop(['Price'], axis = 1)
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Regression Analysis

# %%
from sklearn.metrics import accuracy_score, classification_report, r2_score
from sklearn import metrics

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
prediction = regression.predict(x_test)

# %%
score = round((regression.score(x_test, y_test)*100),2)
print("\nModel Score:",score,"%")
# Out:
# Model Score: 30.85 %

# %%
r2_score(y_test,prediction)
# Out:
# 0.308476289402015

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators=300, random_state=0)
regressor.fit(x,y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
prediction =regressor.predict(x_test)

# %%
score = round((regressor.score(x_test, y_test)*100),2)
print("\nModel Score:", score,"%")
# Out:
# Model Score: 60.38 %

# %%
r2_score(y_test,prediction)
# Out:
# 0.6038241117321705

# %% [markdown]
# ## Support Vector Regression

# %%
from sklearn.svm import SVR

# %%
regressor = SVR(kernel='rbf')
regressor.fit(x,y)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
prediction = regressor.predict(x_test)

# %%
score = round((regressor.score(x_test, y_test)*100),2)
print("\nModel Score:", score,"%")
# Out:
# Model Score: 0.08 %

# %%
r2_score(y_test,prediction)
# Out:
# 0.0007564348451276626

# %% [markdown]
# ## Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regressor = DecisionTreeRegressor()
regressor.fit(x,y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
prediction = regressor.predict(x_test)

# %%
score = round((regressor.score(x_test, y_test)*100),2)
print("\nModel Score:",score,"%")
# Out:
# Model Score: 62.44 %

# %%
r2_score(y_test,prediction)
# Out:
# 0.6244477116041811

# %% [markdown]
# ### Major Deciding Factor of House price

# %%
classifier = RandomForestRegressor()
classifier.fit(x,y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
feature_names = x.columns
importance_frame = pd.DataFrame()
importance_frame['Features'] = x.columns
importance_frame['Importance'] = classifier.feature_importances_
importance_frame = importance_frame.sort_values(by=['Importance'], ascending=True)

# %%
plt.barh([0,1,3,4,5,6], importance_frame['Importance'], align='center', alpha=0.5)
plt.yticks([0,1,3,4,5,6], importance_frame['Features'])
plt.xlabel('Importance')
plt.title('Deciding Factor')
plt.show()

# %% [markdown]
# ## The major deciding factor in the price mappings of melbourne is Distance
