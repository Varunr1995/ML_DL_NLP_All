# %% [markdown]
# # Regression Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("G:/Education/Machine Learning/ML_DATA_FILES/AB_NYC_2019.csv")
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
plt.figure(figsize = (18,20))
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')

# %%
drop = df.drop(['id', 'name', 'host_name', 'last_review'], axis = 1, inplace = True)
df.head(1)
# Out:
#    host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0     2787            Brooklyn    Kensington  40.64749  -73.97237
#
#       room_type  price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0  Private room    149               1                  9               0.21
#
#    calculated_host_listings_count  availability_365
# 0                               6               365

# %%
df.reviews_per_month = df.reviews_per_month.fillna(0)
df.head(1)
# Out:
#    host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0     2787            Brooklyn    Kensington  40.64749  -73.97237
#
#       room_type  price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0  Private room    149               1                  9               0.21
#
#    calculated_host_listings_count  availability_365
# 0                               6               365

# %%
df.isnull().sum()
# Out:
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
# CO-RELATION B/W DIFFERENT VARIABLES #
corr = df.corr(method = 'kendall')
plt.figure(figsize = (20,8))
sns.heatmap(corr, annot = True)
df.columns
# Out:
# Index(['host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
columns = df['neighbourhood_group'].unique()
columns
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
sns.countplot('neighbourhood_group', data = df)

# %%
plt.figure(figsize=(20,10))
sns.countplot('price',hue = 'room_type', data = df)

# %%
plt.figure(figsize=(20,10))
sns.countplot('room_type', data = df)
plt.title("Types of rooms available in AIRBNB")
# Out:
# Text(0.5, 1.0, 'Types of rooms available in AIRBNB')

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df["room_type"].iplot(kind = 'hist', bins = 50)
# Out:
# <div>
#
#
#             <div id="b3b9078e-dca6-42aa-a802-b45aa4b95f42" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b3b9078e-dca6-42aa-a802-b45aa4b95f42")) {
#                     Plotly.newPlot(
#                         'b3b9078e-dca6-42aa-a802-b45aa4b95f42',
#                         [{"histfunc": "count", "histnorm": "", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#4D5663", "width": 1.3}}, "name": "room_type", "nbinsx": 50, "opacity": 0.8, "orientation": "v", "type": "histogram", "x": ["Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Private room", "Private room", "Private room", "Private room", "Private room", "Private room", "Entire home/apt", "Private room", "Shared room", "Private room", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Entire home/apt", "Private room", "Private room", "Private room", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Entire home/apt", "Private room", "Private room", "Private room", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Private room", "Entire home/apt", "Entire home/apt", "Shared room", "Private room", "Private room", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Private room", "Private room", "Entire home/apt", "Private room", " ...

# %%
plt.figure(figsize = (20,10))
plt.title("Availability of rooms in specific neigbourhood")
sns.boxplot(x = 'neighbourhood_group', y = 'availability_365', data = df)

# %%
plt.figure(figsize = (10,6))
sns.scatterplot('longitude', 'latitude', hue = 'neighbourhood_group', data = df)

# %%
plt.figure(figsize = (10,6))
sns.scatterplot('longitude', 'latitude', hue = 'room_type', data = df)

# %%
plt.figure(figsize = (10,6))
sns.scatterplot('longitude', 'latitude', hue = 'availability_365', data = df)

# %%
drop1 = df.drop(['host_id', 'latitude', 'longitude', 'number_of_reviews', 'reviews_per_month'], axis = 1, inplace = True)
df.head(5)
# Out:
#   neighbourhood_group neighbourhood        room_type  price  minimum_nights  \
# 0            Brooklyn    Kensington     Private room    149               1
# 1           Manhattan       Midtown  Entire home/apt    225               1
# 2           Manhattan        Harlem     Private room    150               3
# 3            Brooklyn  Clinton Hill  Entire home/apt     89               1
# 4           Manhattan   East Harlem  Entire home/apt     80              10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
df['room_type'] = pd.get_dummies(df['room_type'])

# %%
df['neighbourhood'] = pd.get_dummies(df['neighbourhood'])

# %%
df['neighbourhood_group'] = pd.get_dummies(df['neighbourhood_group'])

# %%
df.head(2)
# Out:
#    neighbourhood_group  neighbourhood  room_type  price  minimum_nights  \
# 0                    0              0          0    149               1
# 1                    0              0          1    225               1
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:,[0,1,2,4,5,6]]
y = df['price']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 1/3)

# %%
from sklearn.metrics import classification_report, confusion_matrix, r2_score
from sklearn import metrics

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
prediction = lr.predict(x_test)

# %%
score = round((lr.score(x_test, y_test)*100),2)
print("\nModel Score:",score,"%")
# Out:
# Model Score: 10.72 %

# %%
r2_score(y_test,prediction)
# Out:
# 0.10721308670621854

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
lr = KNeighborsClassifier()
lr.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
prediction = lr.predict(x_test)

# %%
score = round((lr.score(x_test, y_test)*100),2)
print("\nModel Score:",score,"%")
# Out:
# Model Score: 3.37 %

# %%
r2_score(y_test,prediction)
# Out:
# -0.06851212265566109

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
lr = DecisionTreeClassifier()
lr.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
prediction = lr.predict(x_test)

# %%
score = round((lr.score(x_test, y_test)*100),2)
print("\nModel Score:",score,"%")
# Out:
# Model Score: 5.8 %

# %%
r2_score(y_test,prediction)
# Out:
# -0.3453981264301671

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
lr = RandomForestClassifier()
lr.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
prediction = lr.predict(x_test)

# %%
score = round((lr.score(x_test, y_test)*100),2)
print("\nModel Score:",score,"%")
# Out:
# Model Score: 5.71 %

# %%
r2_score(y_test,prediction)
# Out:
# -0.6774736804618513

# %% [markdown]
# # SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVC

# %%
lr = SVC()
lr.fit(x_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
prediction = lr.predict(x_test)

# %%
score = round((lr.score(x_test, y_test)*100),2)
print("\nModel Score:",score,"%")
# Out:
# Model Score: 4.48 %

# %%
r2_score(y_test,prediction)
# Out:
# -0.024252987482567434

# %% [markdown]
# * AS PER TO THE R^2 VALUE CONISDERED FROM ALL THE REGRESSORS AND CLASSIFIERS, LINEAR REGRESSION GOT THE MINIMAL ERROR.

# %% [markdown]
# # Deep Learning Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import tensorflow as tf
# Out:
# C:\Users\varun\anaconda3\envs\condaenv\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# C:\Users\varun\anaconda3\envs\condaenv\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# C:\Users\varun\anaconda3\envs\condaenv\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# C:\Users\varun\anaconda3\envs\condaenv\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# C:\Users\varun\anaconda3\envs\condaenv\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# C:\Users\varun\anaconda3\envs\condaenv\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import SGD

# %%
df_tensor = pd.read_csv("G:/Education/Machine Learning/ML_DATA_FILES/AB_NYC_2019.csv")
df_tensor.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df_tensor.drop(columns=['id', 'name', 'host_id', 'host_name', 'latitude', 'longitude', 'last_review', 'number_of_reviews', 'reviews_per_month'], axis = 1, inplace = True)
df_tensor.head()
# Out:
#   neighbourhood_group neighbourhood        room_type  price  minimum_nights  \
# 0            Brooklyn    Kensington     Private room    149               1
# 1           Manhattan       Midtown  Entire home/apt    225               1
# 2           Manhattan        Harlem     Private room    150               3
# 3            Brooklyn  Clinton Hill  Entire home/apt     89               1
# 4           Manhattan   East Harlem  Entire home/apt     80              10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
df_tensor.isnull().sum()
# Out:
# neighbourhood_group               0
# neighbourhood                     0
# room_type                         0
# price                             0
# minimum_nights                    0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df_tensor['neighbourhood_group'] = pd.get_dummies(df_tensor['neighbourhood_group'])
df_tensor['neighbourhood'] = pd.get_dummies(df_tensor['neighbourhood'])
df_tensor['room_type'] = pd.get_dummies(df_tensor['room_type'])

# %%
df_tensor.head(3)
# Out:
#    neighbourhood_group  neighbourhood  room_type  price  minimum_nights  \
# 0                    0              0          0    149               1
# 1                    0              0          1    225               1
# 2                    0              0          0    150               3
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365

# %%
x = df_tensor.drop(['price'], axis = 1)
y = df_tensor['price']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3, random_state = 0)

# %%
scaler.fit(x_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units = 64, input_dim = 6, activation = 'linear'))
# Out:
# WARNING:tensorflow:From C:\Users\varun\anaconda3\envs\condaenv\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
classifier.add(Dense(units = 32, activation = 'linear'))

# %%
classifier.add(Dense(units = 1, activation = 'linear'))

# %%
classifier.compile(optimizer='adam', loss = 'mse', metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\varun\anaconda3\envs\condaenv\lib\site-packages\tensorflow\python\keras\utils\losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
history = classifier.fit(x_train, y_train, epochs = 10)
# Out:
# WARNING:tensorflow:From C:\Users\varun\anaconda3\envs\condaenv\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 34226/34226 [==============================] - 2s 69us/sample - loss: 58527.3148 - acc: 0.0000e+00
# Epoch 2/10
# 34226/34226 [==============================] - 2s 48us/sample - loss: 55510.5897 - acc: 0.0000e+00
# Epoch 3/10
# 34226/34226 [==============================] - 2s 47us/sample - loss: 55518.4320 - acc: 0.0000e+00
# Epoch 4/10
# 34226/34226 [==============================] - 2s 66us/sample - loss: 55514.1575 - acc: 0.0000e+00
# Epoch 5/10
# 34226/34226 [==============================] - 2s 46us/sample - loss: 55511.3479 - acc: 0.0000e+00
# Epoch 6/10
# 34226/34226 [==============================] - 2s 48us/sample - loss: 55507.0124 - acc: 0.0000e+00
# Epoch 7/10
# 34226/34226 [==============================] - 2s 46us/sample - loss: 55504.4867 - acc: 0.0000e+00
# Epoch 8/10
# 34226/34226 [==============================] - 2s 50us/sample - loss: 55508.9416 - acc: 0.0000e+00
# Epoch 9/10
# 34226/34226 [==============================] - 2s 49us/sample - loss: 55507.3558 - acc: 0.0000e+00
# Epoch 10/10
# 34226/34226 [==============================] - 2s 49us/sample - loss: 55504.5781 - acc: 0.0000e+00

# %%
classifier.predict(scaler.transform([[0, 0, 0, 1, 6, 365]]))
# Out:
# array([[122.93308]], dtype=float32)

# %% [markdown]
# ### The actual price of the stay is 149USD whereas the predicted value is 129USD

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
pred_train= classifier.predict(x_train)
print(np.sqrt(mean_squared_error(y_train,pred_train)))

pred= classifier.predict(x_test)
print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 235.65177016718252
# 220.80646035733326

# %%
prediction = classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, r2_score
from sklearn import metrics

# %%
r2_score(y_test,prediction)
# Out:
# 0.08228532930277888
